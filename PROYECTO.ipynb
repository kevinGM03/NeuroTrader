# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinGM03/NeuroTrader/blob/main/PROYECTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Descargar los datos historicos de bitcoin desde 2017 hasta la fecha actual

# %%
import os
import requests
import pandas as pd
from zipfile import ZipFile
from io import BytesIO
from datetime import datetime

# Configuración de la carpeta de destino
output_folder = r'/content/drive/My Drive/PROYECTO/DATOS HISTORICOS'
if not os.path.exists(output_folder):
  os.makedirs(output_folder)

if os.path.exists(output_folder):
    print(f"La carpeta de destino existe: {output_folder}")

    # Fechas de inicio y configuración
    start_year = 2019
    start_month = 1
    end_year = datetime.now().year
    end_month = datetime.now().month
    end_day = datetime.now().day - 1  # Hasta el día anterior al actual
    symbol = 'BTCUSDT'
    interval = '1m'

    # URL base para datos de Binance en la ruta mensual y diaria
    monthly_base_url = 'https://data.binance.vision/data/spot/monthly/klines'
    daily_base_url = 'https://data.binance.vision/data/spot/daily/klines'

    def download_monthly_data(year, month):
        month_str = str(month).zfill(2)
        file_name = f"{symbol}-{interval}-{year}-{month_str}.zip"
        file_url = f"{monthly_base_url}/{symbol}/{interval}/{file_name}"

        yearly_folder = os.path.join(output_folder, f'{year}')
        if not os.path.exists(yearly_folder):
            os.makedirs(yearly_folder)

        output_file = os.path.join(yearly_folder, f'{symbol}_data_{year}_{month_str}.csv')

        # Evitar descarga si el archivo ya existe
        if os.path.exists(output_file):
            print(f"{output_file} ya existe. Saltando descarga del mes completo.")
            return

        # Descargar y guardar archivo mensual
        try:
            print(f"Descargando archivo mensual {file_name} desde {file_url}")
            response = requests.get(file_url, stream=True)
            if response.status_code == 404:
                print(f"Archivo {file_name} no encontrado. Saltando.")
                return

            with ZipFile(BytesIO(response.content)) as thezip:
                csv_file_name = thezip.namelist()[0]
                with thezip.open(csv_file_name) as thefile:
                    df = pd.read_csv(thefile, header=None, names=[
                        'timestamp', 'open', 'high', 'low', 'close', 'volume',
                        'close_time', 'quote_asset_volume', 'number_of_trades',
                        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
                    ])
                    df.to_csv(output_file, index=False)
                    print(f"Datos de {year}-{month_str} guardados en {output_file}")
        except requests.exceptions.RequestException as e:
            print(f"Error al descargar {file_name}: {e}")

    def download_daily_data(year, month, day):
        month_str = str(month).zfill(2)
        day_str = str(day).zfill(2)
        file_name = f"{symbol}-{interval}-{year}-{month_str}-{day_str}.zip"
        file_url = f"{daily_base_url}/{symbol}/{interval}/{file_name}"

        daily_folder = os.path.join(output_folder, f'{year}')
        if not os.path.exists(daily_folder):
            os.makedirs(daily_folder)

        output_file = os.path.join(daily_folder, f'{symbol}_data_{year}_{month_str}_{day_str}.csv')

        # Evitar descarga si el archivo ya existe
        if os.path.exists(output_file):
            print(f"{output_file} ya existe. Saltando descarga del día.")
            return

        # Descargar y guardar archivo diario
        try:
            print(f"Descargando archivo diario {file_name} desde {file_url}")
            response = requests.get(file_url, stream=True)
            if response.status_code == 404:
                print(f"Archivo {file_name} no encontrado. Saltando.")
                return

            with ZipFile(BytesIO(response.content)) as thezip:
                csv_file_name = thezip.namelist()[0]
                with thezip.open(csv_file_name) as thefile:
                    df = pd.read_csv(thefile, header=None, names=[
                        'timestamp', 'open', 'high', 'low', 'close', 'volume',
                        'close_time', 'quote_asset_volume', 'number_of_trades',
                        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
                    ])
                    df.to_csv(output_file, index=False)
                    print(f"Datos de {year}-{month_str}-{day_str} guardados en {output_file}")
        except requests.exceptions.RequestException as e:
            print(f"Error al descargar {file_name}: {e}")

    # Descargar datos mensuales para cada mes hasta el mes actual
    for year in range(start_year, end_year + 1):
        first_month = start_month if year == start_year else 1
        last_month = end_month if year == end_year else 12

        for month in range(first_month, last_month + 1):
            download_monthly_data(year, month)

    # Descargar datos diarios para el mes actual, hasta el día anterior al actual
    for day in range(1, end_day + 1):
        download_daily_data(end_year, end_month, day)

    print("Descarga completa.")
else:
    print(f"Error: La carpeta de destino no se encuentra en {output_folder}")
# Out:
# La carpeta de destino existe: /content/drive/My Drive/PROYECTO/DATOS HISTORICOS
# Descargando archivo mensual BTCUSDT-1m-2019-01.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-01.zip
# Datos de 2019-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_01.csv
# Descargando archivo mensual BTCUSDT-1m-2019-02.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-02.zip
# Datos de 2019-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_02.csv
# Descargando archivo mensual BTCUSDT-1m-2019-03.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-03.zip
# Datos de 2019-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_03.csv
# Descargando archivo mensual BTCUSDT-1m-2019-04.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-04.zip
# Datos de 2019-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_04.csv
# Descargando archivo mensual BTCUSDT-1m-2019-05.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-05.zip
# Datos de 2019-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_05.csv
# Descargando archivo mensual BTCUSDT-1m-2019-06.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-06.zip
# Datos de 2019-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_06.csv
# Descargando archivo mensual BTCUSDT-1m-2019-07.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-07.zip
# Datos de 2019-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_07.csv
# Descargando archivo mensual BTCUSDT-1m-2019-08.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-08.zip
# Datos de 2019-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_08.csv
# Descargando archivo mensual BTCUSDT-1m-2019-09.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-09.zip
# Datos de 2019-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_09.csv
# Descargando archivo mensual BTCUSDT-1m-2019-10.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-10.zip
# Datos de 2019-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_10.csv
# Descargando archivo mensual BTCUSDT-1m-2019-11.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-11.zip
# Datos de 2019-11 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_11.csv
# Descargando archivo mensual BTCUSDT-1m-2019-12.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2019-12.zip
# Datos de 2019-12 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2019/BTCUSDT_data_2019_12.csv
# Descargando archivo mensual BTCUSDT-1m-2020-01.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-01.zip
# Datos de 2020-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_01.csv
# Descargando archivo mensual BTCUSDT-1m-2020-02.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-02.zip
# Datos de 2020-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_02.csv
# Descargando archivo mensual BTCUSDT-1m-2020-03.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-03.zip
# Datos de 2020-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_03.csv
# Descargando archivo mensual BTCUSDT-1m-2020-04.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-04.zip
# Datos de 2020-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_04.csv
# Descargando archivo mensual BTCUSDT-1m-2020-05.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-05.zip
# Datos de 2020-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_05.csv
# Descargando archivo mensual BTCUSDT-1m-2020-06.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-06.zip
# Datos de 2020-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_06.csv
# Descargando archivo mensual BTCUSDT-1m-2020-07.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-07.zip
# Datos de 2020-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_07.csv
# Descargando archivo mensual BTCUSDT-1m-2020-08.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-08.zip
# Datos de 2020-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_08.csv
# Descargando archivo mensual BTCUSDT-1m-2020-09.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-09.zip
# Datos de 2020-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_09.csv
# Descargando archivo mensual BTCUSDT-1m-2020-10.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-10.zip
# Datos de 2020-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_10.csv
# Descargando archivo mensual BTCUSDT-1m-2020-11.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-11.zip
# Datos de 2020-11 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_11.csv
# Descargando archivo mensual BTCUSDT-1m-2020-12.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2020-12.zip
# Datos de 2020-12 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2020/BTCUSDT_data_2020_12.csv
# Descargando archivo mensual BTCUSDT-1m-2021-01.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-01.zip
# Datos de 2021-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_01.csv
# Descargando archivo mensual BTCUSDT-1m-2021-02.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-02.zip
# Datos de 2021-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_02.csv
# Descargando archivo mensual BTCUSDT-1m-2021-03.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-03.zip
# Datos de 2021-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_03.csv
# Descargando archivo mensual BTCUSDT-1m-2021-04.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-04.zip
# Datos de 2021-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_04.csv
# Descargando archivo mensual BTCUSDT-1m-2021-05.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-05.zip
# Datos de 2021-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_05.csv
# Descargando archivo mensual BTCUSDT-1m-2021-06.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-06.zip
# Datos de 2021-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_06.csv
# Descargando archivo mensual BTCUSDT-1m-2021-07.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-07.zip
# Datos de 2021-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_07.csv
# Descargando archivo mensual BTCUSDT-1m-2021-08.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-08.zip
# Datos de 2021-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_08.csv
# Descargando archivo mensual BTCUSDT-1m-2021-09.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-09.zip
# Datos de 2021-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_09.csv
# Descargando archivo mensual BTCUSDT-1m-2021-10.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-10.zip
# Datos de 2021-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_10.csv
# Descargando archivo mensual BTCUSDT-1m-2021-11.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-11.zip
# Datos de 2021-11 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_11.csv
# Descargando archivo mensual BTCUSDT-1m-2021-12.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2021-12.zip
# Datos de 2021-12 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2021/BTCUSDT_data_2021_12.csv
# Descargando archivo mensual BTCUSDT-1m-2022-01.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-01.zip
# Datos de 2022-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_01.csv
# Descargando archivo mensual BTCUSDT-1m-2022-02.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-02.zip
# Datos de 2022-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_02.csv
# Descargando archivo mensual BTCUSDT-1m-2022-03.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-03.zip
# Datos de 2022-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_03.csv
# Descargando archivo mensual BTCUSDT-1m-2022-04.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-04.zip
# Datos de 2022-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_04.csv
# Descargando archivo mensual BTCUSDT-1m-2022-05.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-05.zip
# Datos de 2022-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_05.csv
# Descargando archivo mensual BTCUSDT-1m-2022-06.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-06.zip
# Datos de 2022-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_06.csv
# Descargando archivo mensual BTCUSDT-1m-2022-07.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-07.zip
# Datos de 2022-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_07.csv
# Descargando archivo mensual BTCUSDT-1m-2022-08.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-08.zip
# Datos de 2022-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_08.csv
# Descargando archivo mensual BTCUSDT-1m-2022-09.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-09.zip
# Datos de 2022-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_09.csv
# Descargando archivo mensual BTCUSDT-1m-2022-10.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-10.zip
# Datos de 2022-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_10.csv
# Descargando archivo mensual BTCUSDT-1m-2022-11.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-11.zip
# Datos de 2022-11 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_11.csv
# Descargando archivo mensual BTCUSDT-1m-2022-12.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-12.zip
# Datos de 2022-12 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2022/BTCUSDT_data_2022_12.csv
# Descargando archivo mensual BTCUSDT-1m-2023-01.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-01.zip
# Datos de 2023-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_01.csv
# Descargando archivo mensual BTCUSDT-1m-2023-02.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-02.zip
# Datos de 2023-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_02.csv
# Descargando archivo mensual BTCUSDT-1m-2023-03.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-03.zip
# Datos de 2023-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_03.csv
# Descargando archivo mensual BTCUSDT-1m-2023-04.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-04.zip
# Datos de 2023-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_04.csv
# Descargando archivo mensual BTCUSDT-1m-2023-05.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-05.zip
# Datos de 2023-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_05.csv
# Descargando archivo mensual BTCUSDT-1m-2023-06.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-06.zip
# Datos de 2023-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_06.csv
# Descargando archivo mensual BTCUSDT-1m-2023-07.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-07.zip
# Datos de 2023-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_07.csv
# Descargando archivo mensual BTCUSDT-1m-2023-08.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-08.zip
# Datos de 2023-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_08.csv
# Descargando archivo mensual BTCUSDT-1m-2023-09.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-09.zip
# Datos de 2023-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_09.csv
# Descargando archivo mensual BTCUSDT-1m-2023-10.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-10.zip
# Datos de 2023-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_10.csv
# Descargando archivo mensual BTCUSDT-1m-2023-11.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-11.zip
# Datos de 2023-11 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_11.csv
# Descargando archivo mensual BTCUSDT-1m-2023-12.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2023-12.zip
# Datos de 2023-12 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2023/BTCUSDT_data_2023_12.csv
# Descargando archivo mensual BTCUSDT-1m-2024-01.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-01.zip
# Datos de 2024-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_01.csv
# Descargando archivo mensual BTCUSDT-1m-2024-02.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-02.zip
# Datos de 2024-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_02.csv
# Descargando archivo mensual BTCUSDT-1m-2024-03.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-03.zip
# Datos de 2024-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_03.csv
# Descargando archivo mensual BTCUSDT-1m-2024-04.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-04.zip
# Datos de 2024-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_04.csv
# Descargando archivo mensual BTCUSDT-1m-2024-05.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-05.zip
# Datos de 2024-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_05.csv
# Descargando archivo mensual BTCUSDT-1m-2024-06.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-06.zip
# Datos de 2024-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_06.csv
# Descargando archivo mensual BTCUSDT-1m-2024-07.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-07.zip
# Datos de 2024-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_07.csv
# Descargando archivo mensual BTCUSDT-1m-2024-08.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-08.zip
# Datos de 2024-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_08.csv
# Descargando archivo mensual BTCUSDT-1m-2024-09.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-09.zip
# Datos de 2024-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_09.csv
# Descargando archivo mensual BTCUSDT-1m-2024-10.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-10.zip
# Datos de 2024-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_10.csv
# Descargando archivo mensual BTCUSDT-1m-2024-11.zip desde https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11.zip
# Archivo BTCUSDT-1m-2024-11.zip no encontrado. Saltando.
# Descargando archivo diario BTCUSDT-1m-2024-11-01.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-01.zip
# Datos de 2024-11-01 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_01.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-02.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-02.zip
# Datos de 2024-11-02 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_02.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-03.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-03.zip
# Datos de 2024-11-03 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_03.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-04.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-04.zip
# Datos de 2024-11-04 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_04.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-05.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-05.zip
# Datos de 2024-11-05 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_05.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-06.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-06.zip
# Datos de 2024-11-06 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_06.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-07.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-07.zip
# Datos de 2024-11-07 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_07.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-08.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-08.zip
# Datos de 2024-11-08 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_08.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-09.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-09.zip
# Datos de 2024-11-09 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_09.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-10.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-10.zip
# Datos de 2024-11-10 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_10.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-11.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-11.zip
# Datos de 2024-11-11 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_11.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-12.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-12.zip
# Datos de 2024-11-12 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_12.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-13.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-13.zip
# Datos de 2024-11-13 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_13.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-14.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-14.zip
# Datos de 2024-11-14 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_14.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-15.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-15.zip
# Datos de 2024-11-15 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_15.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-16.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-16.zip
# Datos de 2024-11-16 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_16.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-17.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-17.zip
# Datos de 2024-11-17 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_17.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-18.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-18.zip
# Datos de 2024-11-18 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_18.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-19.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-19.zip
# Datos de 2024-11-19 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_19.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-20.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-20.zip
# Datos de 2024-11-20 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_20.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-21.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-21.zip
# Datos de 2024-11-21 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_21.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-22.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-22.zip
# Datos de 2024-11-22 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_22.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-23.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-23.zip
# Datos de 2024-11-23 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_23.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-24.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-24.zip
# Datos de 2024-11-24 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_24.csv
# Descargando archivo diario BTCUSDT-1m-2024-11-25.zip desde https://data.binance.vision/data/spot/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2024-11-25.zip
# Datos de 2024-11-25 guardados en /content/drive/My Drive/PROYECTO/DATOS HISTORICOS/2024/BTCUSDT_data_2024_11_25.csv
# Descarga completa.

# %% [markdown]
# Calcular los indicadores tecnicos y crear el Dataset completo

# %%
import os
import pandas as pd

# Ruta del directorio raíz que contiene las carpetas por año
root_folder = r'/content/drive/My Drive/PROYECTO/DATOS HISTORICOS'

# Crear una lista para almacenar todos los DataFrames
all_data = []

# Recorrer las carpetas de cada año
for year_folder in os.listdir(root_folder):
    year_path = os.path.join(root_folder, year_folder)

    # Verificar si es una carpeta
    if os.path.isdir(year_path):
        # Recorrer los archivos dentro de la carpeta del año
        for file_name in os.listdir(year_path):
            if file_name.endswith('.csv'):
                file_path = os.path.join(year_path, file_name)

                # Leer el archivo CSV
                df = pd.read_csv(file_path)

                # Agregar los datos al conjunto
                all_data.append(df)

# Combinar todos los DataFrames en uno solo
if all_data:
    historical_data = pd.concat(all_data, ignore_index=True)

    # Asegúrate de que los datos estén ordenados por el tiempo
    historical_data.sort_values(by='timestamp', inplace=True)
    historical_data.reset_index(drop=True, inplace=True)

    # Funciones para calcular indicadores técnicos
    def calculate_indicators(df):
        # Media Móvil (MA) de 20 y 50 periodos
        df['MA_20'] = df['close'].rolling(window=20).mean()
        df['MA_50'] = df['close'].rolling(window=50).mean()

        # RSI de 14 periodos
        df['RSI'] = calculate_rsi(df['close'], 14)

        # Bandas de Bollinger de 20 periodos
        df['Bollinger_Upper'], df['Bollinger_Lower'] = calculate_bollinger_bands(df['close'], window=20)

        return df

    def calculate_rsi(series, period=14):
        delta = series.diff()
        gain = (delta.where(delta > 0, 0)).rolling(window=period).mean()
        loss = (-delta.where(delta < 0, 0)).rolling(window=period).mean()
        rs = gain / loss
        return 100 - (100 / (1 + rs))

    def calculate_bollinger_bands(series, window=20):
        ma = series.rolling(window).mean()
        std = series.rolling(window).std()
        upper_band = ma + (std * 2)
        lower_band = ma - (std * 2)
        return upper_band, lower_band

    # Aplicar el cálculo de indicadores técnicos
    historical_data = calculate_indicators(historical_data)

    # Eliminar filas con valores faltantes
    historical_data.dropna(inplace=True)

    # Guardar el DataFrame con indicadores en un nuevo archivo CSV
    output_file = r'/content/drive/My Drive/PROYECTO/DATASET/Dataset.csv'
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    historical_data.to_csv(output_file, index=False)
    print(f"Archivo con indicadores técnicos guardado como '{output_file}'")
else:
    print("No se encontraron datos para procesar.")
# Out:
# Archivo con indicadores técnicos guardado como '/content/drive/My Drive/PROYECTO/DATASET/Dataset.csv'

# %% [markdown]
# Prepara el Dataset

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler

# Configuración
input_file = r'/content/drive/My Drive/PROYECTO/DATASET/Dataset.csv'
output_folder = r'/content/drive/My Drive/PROYECTO/DATASET_PREPARADO'
os.makedirs(output_folder, exist_ok=True)

sequence_length = 60  # Ventana de 60 minutos
features = [
    'open', 'high', 'low', 'close',
    'MA_20', 'MA_50',
    'RSI', 'Bollinger_Upper', 'Bollinger_Lower',
    'quote_asset_volume', 'number_of_trades',
    'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume'
]
target = 'close'

# Leer el dataset en chunks
chunk_size = 10**6  # Leer en bloques de 1 millón de filas
chunks = pd.read_csv(input_file, chunksize=chunk_size)

# Combinar todos los chunks para dividir los datos
df = pd.concat(chunks, ignore_index=True)

# Eliminar filas con valores faltantes
df.dropna(inplace=True)

# Dividir el dataset en entrenamiento (60%), validación (10%) y prueba (30%)
train_size = int(len(df) * 0.60)
val_size = int(len(df) * 0.10)

train_df = df[:train_size]
val_df = df[train_size:train_size + val_size]
test_df = df[train_size + val_size:]

# Escalador para normalizar las características
scaler = MinMaxScaler()

# Crear copias explícitas de los subconjuntos para evitar conflictos
train_df = train_df.copy()
val_df = val_df.copy()
test_df = test_df.copy()

# Aplicar la normalización
train_df.loc[:, features] = scaler.fit_transform(train_df[features])
val_df.loc[:, features] = scaler.transform(val_df[features])
test_df.loc[:, features] = scaler.transform(test_df[features])

# Función para procesar ventanas temporales y guardar lotes en bloques
def process_and_save_batches(data, set_name):
    num_rows = len(data)
    num_chunks = num_rows // (chunk_size // sequence_length) + 1

    X_data = data[features].values
    y_data = data[target].values

    for chunk_index in range(num_chunks):
        start_idx = chunk_index * (chunk_size // sequence_length)
        end_idx = min(start_idx + (chunk_size // sequence_length), num_rows - sequence_length)

        if start_idx >= end_idx:  # Evitar chunks vacíos
            break

        X, y = [], []
        for i in range(start_idx, end_idx):
            X.append(X_data[i:i + sequence_length])
            y.append(y_data[i + sequence_length])

        # Convertir a numpy arrays
        X = np.array(X)
        y = np.array(y)

        # Guardar el bloque
        np.save(os.path.join(output_folder, f"X_{set_name}_chunk{chunk_index}.npy"), X)
        np.save(os.path.join(output_folder, f"y_{set_name}_chunk{chunk_index}.npy"), y)
        print(f"Chunk {chunk_index + 1}/{num_chunks} del {set_name} guardado: X shape = {X.shape}, y shape = {y.shape}")

# Procesar y guardar cada conjunto
process_and_save_batches(train_df, "train")
process_and_save_batches(val_df, "val")
process_and_save_batches(test_df, "test")

print("Procesamiento y guardado de lotes completado.")
# Out:
# <ipython-input-2-f1f88886f8f2>:48: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.00255523 0.00202968 0.00170348 ... 0.05958573 0.08160418 0.08778384]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[:, features] = scaler.fit_transform(train_df[features])
# <ipython-input-2-f1f88886f8f2>:49: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.0741922  0.06366322 0.09332923 ... 0.06565666 0.12765263 0.07479024]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   val_df.loc[:, features] = scaler.transform(val_df[features])
# <ipython-input-2-f1f88886f8f2>:50: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.07087584 0.10021565 0.11342672 ... 0.0746815  0.05809971 0.05911455]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   test_df.loc[:, features] = scaler.transform(test_df[features])
# Chunk 1/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 2/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 3/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 4/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 5/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 6/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 7/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 8/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 9/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 10/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 11/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 12/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 13/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 14/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 15/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 16/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 17/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 18/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 19/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 20/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 21/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 22/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 23/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 24/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 25/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 26/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 27/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 28/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 29/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 30/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 31/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 32/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 33/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 34/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 35/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 36/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 37/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 38/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 39/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 40/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 41/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 42/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 43/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 44/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 45/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 46/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 47/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 48/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 49/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 50/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 51/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 52/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 53/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 54/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 55/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 56/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 57/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 58/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 59/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 60/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 61/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 62/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 63/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 64/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 65/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 66/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 67/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 68/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 69/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 70/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 71/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 72/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 73/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 74/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 75/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 76/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 77/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 78/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 79/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 80/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 81/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 82/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 83/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 84/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 85/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 86/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 87/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 88/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 89/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 90/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 91/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 92/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 93/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 94/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 95/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 96/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 97/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 98/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 99/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 100/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 101/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 102/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 103/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 104/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 105/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 106/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 107/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 108/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 109/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 110/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 111/112 del train guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 112/112 del train guardado: X shape = (9988, 60, 13), y shape = (9988,)
# Chunk 1/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 2/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 3/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 4/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 5/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 6/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 7/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 8/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 9/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 10/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 11/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 12/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 13/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 14/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 15/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 16/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 17/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 18/19 del val guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 19/19 del val guardado: X shape = (9947, 60, 13), y shape = (9947,)
# Chunk 1/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 2/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 3/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 4/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 5/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 6/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 7/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 8/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 9/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 10/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 11/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 12/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 13/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 14/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 15/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 16/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 17/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 18/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 19/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 20/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 21/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 22/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 23/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 24/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 25/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 26/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 27/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 28/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 29/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 30/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 31/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 32/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 33/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 34/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 35/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 36/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 37/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 38/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 39/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 40/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 41/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 42/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 43/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 44/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 45/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 46/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 47/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 48/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 49/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 50/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 51/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 52/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 53/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 54/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 55/56 del test guardado: X shape = (16666, 60, 13), y shape = (16666,)
# Chunk 56/56 del test guardado: X shape = (13298, 60, 13), y shape = (13298,)
# Procesamiento y guardado de lotes completado.

# %%
# Importar Tensorflow y mostrar su versión
import tensorflow as tf

print('TensorFlow version:', tf.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.17.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Importar librerías
import tensorflow as tf
import numpy as np

# La librería logging es un medio para rastrear eventos que ocurren cuando se ejecuta un script.
# El componente tf.logger() de TF tiene programado enviar logs a este logger cuando exista algún error
# en la ejecución.
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

print('Versión de TensorFlow:', tf.__version__)
print('Versión de Keras:', tf.keras.__version__)
print('Probar GPU' if tf.test.is_gpu_available() else 'No se encontró GPU. Corriendo en CPU')

# Establecer la semilla aleatoria para que los números generados sean reproducibles
tf.random.set_seed(7)

# Crear 3 características aleatorias
features = tf.random.normal((1, 3))

# Crear 3 pesos aleatorios para nuestra red neuronal
weights = tf.random.normal((1, 3))

# Crear un bias aleatorio
bias = tf.random.normal((1, 1))

print('Features:\n', features)
print('\nWeights:\n', weights)
print('\nBias:\n', bias)

def sigmoid_activation(x):
    """ Función de activación sigmoidal

        Argumentos
        ---------
        x: tf.Tensor. Tendra que ser uno de los siguientes tipos: bfloat16, half, float32, float64, complex64, complex128.
    """
    return 1/(1+tf.exp(-x))

y = sigmoid_activation(tf.reduce_sum(tf.multiply(features, weights)) + bias)

print('label:\n', y)
# Out:
# Versión de TensorFlow: 2.17.1
# Versión de Keras: 3.5.0
# Probar GPU
# Features:
#  tf.Tensor([[0.5983449  0.06276207 0.14631742]], shape=(1, 3), dtype=float32)
#
# Weights:
#  tf.Tensor([[-2.2733312 -1.6592104 -0.2633568]], shape=(1, 3), dtype=float32)
#
# Bias:
#  tf.Tensor([[1.5749501]], shape=(1, 1), dtype=float32)
# label:
#  tf.Tensor([[0.5180034]], shape=(1, 1), dtype=float32)

# %%
# Establecer la semilla aleatoria para que los números generados sean reproducibles
tf.random.set_seed(7)

# Crear 3 datos de entrada (características aleatorias)
features = tf.random.normal((1,3))

# Definir el tamaño de cada capa en nuestra red
n_input = features.shape[1]     # Número de unidades de entrada, debe coincidir con el número de unidades de entrada
n_hidden = 2                    # Número de unidades ocultas
n_output = 1                    # Número de unidades de salida

# Crear los pesos aleatorios para las conexiones que van desde las entradas hacia la capa oculta
W1 = tf.random.normal((n_input,n_hidden))

# Crear pesos aleatorios para las conexiones que van desde la capa oculta hacia la capa de salida
W2 = tf.random.normal((n_hidden, n_output))

# Crear bias aleatorios para la capa oculta y la de salida
B1 = tf.random.normal((1,n_hidden))
B2 = tf.random.normal((1, n_output))

# Aplicar la función de activación sigmoidal
h = sigmoid_activation(tf.matmul(features, W1) + B1)
output = sigmoid_activation(tf.matmul(h, W2) + B2)

# Mostrar el resultado
print(output)
# Out:
# tf.Tensor([[0.10678572]], shape=(1, 1), dtype=float32)
